# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
# Numerical python

import pandas as pd
# data processing 

import seaborn as sns
# pip install seaborn, used for visualizations 

import matplotlib.pyplot as plt
# visualizations

from collections import Counter
# Values count - to count values in species column

from sklearn.neighbors import KNeighborsClassifier
# Sklearn is a library, in which ML algorithms are stored.

# %% [markdown]
# ### Loading and processing dataset

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width       specie
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   specie        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna()
# Out:
#      sepal length  sepal width  petal length  petal width  specie
# 0           False        False         False        False   False
# 1           False        False         False        False   False
# 2           False        False         False        False   False
# 3           False        False         False        False   False
# 4           False        False         False        False   False
# ..            ...          ...           ...          ...     ...
# 145         False        False         False        False   False
# 146         False        False         False        False   False
# 147         False        False         False        False   False
# 148         False        False         False        False   False
# 149         False        False         False        False   False
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# specie          0
# dtype: int64

# %% [markdown]
# ### A visualization

# %%
sns.countplot(data = df, x="specie")
# Out:
# <Axes: xlabel='specie', ylabel='count'>

# %%
count = Counter(df['specie'])
count
# Out:
# Counter({'Iris-setosa': 50, 'Iris-versicolor': 50, 'Iris-virginica': 50})

# %%
count.keys()
# Out:
# dict_keys(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'])

# %%
count.values()
# Out:
# dict_values([50, 50, 50])

# %%
names = list(count.keys())
names
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
values = list(count.values())
values
# Out:
# [50, 50, 50]

# %%
plt.pie(values, labels = names, autopct = '%.1f%%')
plt.show()

# %% [markdown]
# ### creating an object of model

# %%
knn = KNeighborsClassifier()
#decide the n_neighbors
#creating an object of model

# %%
knn
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Seperating features and labels

# %%
features= df[["sepal length", "sepal width",	"petal length",	"petal width"]]

# %%
labels= df["specie"]

# %%
features.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
labels.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: specie, dtype: object

# %% [markdown]
# ### Training model

# %%
knn.fit(features, labels)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Predictions from model

# %%
# sepal length = 4.5
# sepal width = 1.3
# petal length = 4.6
# petal width = 7.8

knn.predict([[4.5, 1.3, 4.6, 6.7]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-virginica'], dtype=object)

# %% [markdown]
# ### Creating data

# %%
new_data = pd.DataFrame([[4.5,1.3,4.6,6.7], [2.0, 1.0, 1.2, 0.2]], columns=["sepal length","sepal width",	"petal length",	"petal width"])
#knn.predict(new_data)

# %%
new_data
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           4.5          1.3           4.6          6.7
# 1           2.0          1.0           1.2          0.2

# %%
knn.predict(new_data)
# Out:
# array(['Iris-virginica', 'Iris-setosa'], dtype=object)

# %% [markdown]
# ## making predictions on the basis of user input

# %%
sepal_l= float(input("Enter your sepal length (cm) : "))
sepal_w= float(input("Enter your sepal width (cm) : "))
petal_l= float(input("Enter your petal length (cm) : "))
petal_w= float(input("Enter your petal width (cm) : "))

user_data= [[sepal_l,sepal_w,petal_l,petal_w]]

# we have to make a 2D array
# Out:
# Enter your sepal length (cm) :  4
# Enter your sepal width (cm) :  6
# Enter your petal length (cm) :  5
# Enter your petal width (cm) :  2

# %%
knn.predict(user_data)[0]
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 'Iris-versicolor'
